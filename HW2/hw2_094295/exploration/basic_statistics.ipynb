# %%
import os
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First we will try to understand how many examples of each class we have. In order to understand the starting balance of the data.

# %%
total = 0
easy_view_dict = dict()
for folder in sorted(glob('/home/student/Data-analysis-and-presentation/HW2/hw2_094295/data/train/*')):
    numeral = folder.split(sep='/')[-1]
    # print(numeral)
    folder_size = len(glob(folder+'/*.png'))
    # print(folder_size)
    total += folder_size
    easy_view_dict[numeral] = folder_size
print(f"Total of {total} pictures")
pd.DataFrame.from_dict(data=easy_view_dict, orient='index')
# Out:
# Total of 2067 pictures
#         0
# i     261
# ii    157
# iii   186
# iv    281
# ix    234
# v     196
# vi    181
# vii   193
# viii  199
# x     179

# %% [markdown]
# As we can see, we do not exceed the 10,000 limit at first. Therefore we will use this to create a baseline.
# We also manually examined the beginning validation set and there are no total mistakes

# %%
os.path.exists('/home/student/Data-analysis-and-presentation/HW2/hw2_094295/code/run_train_eval.py')
# Out:
# False

# %%
# %run /home/student/Data-analysis-and-presentation/HW2/hw2_094295/code/run_train_eval.py
# Out:
# Your working directory is:  /home/student/Data-analysis-and-presentation/HW2/hw2_094295/exploration
# The classes are:  ['i', 'ii', 'iii', 'iv', 'ix', 'v', 'vi', 'vii', 'viii', 'x']
# Epoch 1/15
# ----------
# 100%|██████████| 130/130 [00:49<00:00,  2.63it/s]
# train Loss: 2.5375 Acc: 0.2104
# 100%|██████████| 1/1 [00:00<00:00, 14.36it/s]
# val Loss: 2.1797 Acc: 0.2000
#
# Epoch 2/15
# ----------
# 100%|██████████| 130/130 [00:49<00:00,  2.62it/s]
# train Loss: 1.7151 Acc: 0.4403
# 100%|██████████| 1/1 [00:00<00:00, 15.03it/s]
# val Loss: 2.2689 Acc: 0.5000
#
# Epoch 3/15
# ----------
# 100%|██████████| 130/130 [00:50<00:00,  2.59it/s]
# train Loss: 1.1729 Acc: 0.6173
# 100%|██████████| 1/1 [00:00<00:00, 14.83it/s]
# val Loss: 0.8567 Acc: 0.6000
#
# Epoch 4/15
# ----------
# 100%|██████████| 130/130 [00:50<00:00,  2.58it/s]
# train Loss: 1.0197 Acc: 0.6788
# 100%|██████████| 1/1 [00:00<00:00, 14.29it/s]
# val Loss: 1.1304 Acc: 0.4000
#
# Epoch 5/15
# ----------
# ...
